# %%
#import libraries
import pandas as pd

# %%
#loading IMDB movie_metadata.csv
movie_df = pd.read_csv('movie_metadata.csv')

# %%
movie_df.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# ...

# %%
movie_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5043 entries, 0 to 5042
# Data columns (total 28 columns):
# color                        5024 non-null object
# director_name                4939 non-null object
# num_critic_for_reviews       4993 non-null float64
# duration                     5028 non-null float64
# director_facebook_likes      4939 non-null float64
# actor_3_facebook_likes       5020 non-null float64
# actor_2_name                 5030 non-null object
# actor_1_facebook_likes       5036 non-null float64
# gross                        4159 non-null float64
# genres                       5043 non-null object
# actor_1_name                 5036 non-null object
# movie_title                  5043 non-null object
# num_voted_users              5043 non-null int64
# cast_total_facebook_likes    5043 non-null int64
# actor_3_name                 5020 non-null object
# facenumber_in_poster         5030 non-null float64
# ...

# %%
#Creating dataframe of key columns from original df
movie_df_keyc = movie_df[['actor_1_name','actor_2_name','actor_3_name','genres','director_name','budget','gross']].copy()

# %%
movie_df_keyc.head()
# Out:
#       actor_1_name      actor_2_name          actor_3_name  \
# 0      CCH Pounder  Joel David Moore             Wes Studi
# 1      Johnny Depp     Orlando Bloom        Jack Davenport
# 2  Christoph Waltz      Rory Kinnear      Stephanie Sigman
# 3        Tom Hardy    Christian Bale  Joseph Gordon-Levitt
# 4      Doug Walker        Rob Walker                   NaN
#
#                             genres      director_name       budget  \
# 0  Action|Adventure|Fantasy|Sci-Fi      James Cameron  237000000.0
# 1         Action|Adventure|Fantasy     Gore Verbinski  300000000.0
# 2        Action|Adventure|Thriller         Sam Mendes  245000000.0
# 3                  Action|Thriller  Christopher Nolan  250000000.0
# 4                      Documentary        Doug Walker          NaN
#
#          gross
# 0  760505847.0
# 1  309404152.0
# 2  200074175.0
# 3  448130642.0
# 4          NaN

# %%
#function to calculate profitability
def calc_profit(row):
    return (row['gross']-row['budget'])

# %%
#Adding new column profitability 
movie_df_keyc['profitability']=movie_df_keyc.apply(calc_profit,axis=1)

# %%
movie_df_keyc.head()
# Out:
#       actor_1_name      actor_2_name          actor_3_name  \
# 0      CCH Pounder  Joel David Moore             Wes Studi
# 1      Johnny Depp     Orlando Bloom        Jack Davenport
# 2  Christoph Waltz      Rory Kinnear      Stephanie Sigman
# 3        Tom Hardy    Christian Bale  Joseph Gordon-Levitt
# 4      Doug Walker        Rob Walker                   NaN
#
#                             genres      director_name       budget  \
# 0  Action|Adventure|Fantasy|Sci-Fi      James Cameron  237000000.0
# 1         Action|Adventure|Fantasy     Gore Verbinski  300000000.0
# 2        Action|Adventure|Thriller         Sam Mendes  245000000.0
# 3                  Action|Thriller  Christopher Nolan  250000000.0
# 4                      Documentary        Doug Walker          NaN
#
#          gross  profitability
# 0  760505847.0    523505847.0
# 1  309404152.0      9404152.0
# 2  200074175.0    -44925825.0
# 3  448130642.0    198130642.0
# 4          NaN            NaN

# %%
#sorting dataframe by profitability in decreasing order 
sort_by_profit = movie_df_keyc.sort_values(['profitability'], ascending=[False])

# %%
#Computing the top 10 genres in decreasing order by their profitability
sort_by_profit[['genres','profitability']].head(10)
# Out:
#                                         genres  profitability
# 0              Action|Adventure|Fantasy|Sci-Fi    523505847.0
# 29            Action|Adventure|Sci-Fi|Thriller    502177271.0
# 26                               Drama|Romance    458672302.0
# 3024           Action|Adventure|Fantasy|Sci-Fi    449935665.0
# 3080                             Family|Sci-Fi    424449459.0
# 794                    Action|Adventure|Sci-Fi    403279547.0
# 17                     Action|Adventure|Sci-Fi    403279547.0
# 509   Adventure|Animation|Drama|Family|Musical    377783777.0
# 240            Action|Adventure|Fantasy|Sci-Fi    359544677.0
# 66                 Action|Crime|Drama|Thriller    348316061.0

# %%
#Returning the top 10 actors or directors in decreasing order by their profitability
sort_by_profit[['actor_1_name','actor_2_name','actor_3_name']].head(10)
# Out:
#              actor_1_name       actor_2_name        actor_3_name
# 0             CCH Pounder   Joel David Moore           Wes Studi
# 29    Bryce Dallas Howard         Judy Greer             Omar Sy
# 26      Leonardo DiCaprio       Kate Winslet       Gloria Stuart
# 3024        Harrison Ford      Peter Cushing         Kenny Baker
# 3080         Henry Thomas        Dee Wallace        Peter Coyote
# 794       Chris Hemsworth  Robert Downey Jr.  Scarlett Johansson
# 17        Chris Hemsworth  Robert Downey Jr.  Scarlett Johansson
# 509     Matthew Broderick        Nathan Lane       Niketa Calame
# 240       Natalie Portman        Liam Neeson       Ian McDiarmid
# 66         Christian Bale       Heath Ledger      Morgan Freeman

# %%
#Finding the best actor, director pairs (up to 10) that have the highest IMDB_ratings, if there are indeed any such pairs.
def best_actor_director(row):
    #Considering imdb rating more than or equal to 8 as hightest IMDB_rated
    if row['imdb_score']>=8:
        return (row['actor_1_name'],row['director_name'])

# %%
movie_df.apply(best_actor_director,axis=1).head(10)
# Out:
# 0                              None
# 1                              None
# 2                              None
# 3    (Tom Hardy, Christopher Nolan)
# 4                              None
# 5                              None
# 6                              None
# 7                              None
# 8                              None
# 9                              None
# dtype: object

# %%
ss = pd.Series
